# %% [markdown]
# <a href="https://colab.research.google.com/github/MoneerahAlboulayan/info5731/blob/master/alboulayan_Assign3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 3
#
# In this assignment, you will try to gather information from open data via API and visualize them.
#
# We will use the API from wikipedia as an example.
#
# Please go to [this web page](https://wikitech.wikimedia.org/wiki/Analytics/AQS/Pageviews), to learn how to get Pageviews of a certain wikipedia page.
#
# ![](https://github.com/wshuyi/github_pub_img/raw/master/assets/2019-02-13-10-57-35-202134.png)
#
# As you can see here, to get a pageview count timeseries of en.wikipedia's article "[Albert Enstein](https://en.wikipedia.org/wiki/Albert_Einstein)" for the month of October 2015, you can use the following url with a "GET" method.
#
# [https://wikimedia.org/api/rest\_v1/metrics/pageviews/per-article/en.wikipedia/all-access/all-agents/Albert\_Einstein/daily/2015100100/2015103100](https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/en.wikipedia/all-access/all-agents/Albert_Einstein/daily/2015100100/2015103100)
#
# Your task, is to get Pageviews count timeseries of en.wikipedia's article "[University of North Texas](https://en.wikipedia.org/wiki/University_of_North_Texas)" for the month of January 2019.
#
#
# ![](https://github.com/wshuyi/github_pub_img/raw/master/assets/2019-02-13-10-57-35-210502.png)
#
# Please answer the following questions by putting your code in the corresponding chunks. You can create new code or text chunks if necessary.

# %% [markdown]
# **Question 1. (20 points)** Make the corresponding url to gather the required data, and save it into a variable called 'url'.

# %%
url='https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/en.wikipedia/all-access/all-agents/University_of_North_Texas/daily/2019010100/2019013100'

# %% [markdown]
# **Question 2. (20 points)** Call the API by using the url you created in Question 1, and print out the JSON data. (If you are not familiar with JSON format, please follow [this link](https://en.wikipedia.org/wiki/JSON). Also, you can visit [this link](https://www.w3schools.com/python/python_json.asp) to know how to operate on JSON data with Python. )
#
# ![](https://github.com/wshuyi/github_pub_img/raw/master/assets/2019-02-13-10-57-35-196474.png)

# %%
import json
import requests
import pandas as pd

response=requests.get(url)
data_dict = json.loads(response.text)
data_dict
# Out:
# {'items': [{'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019010100',
#    'views': 732},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019010200',
#    'views': 834},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019010300',
#    'views': 821},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019010400',
#    'views': 719},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019010500',
#    'views': 672},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019010600',
#    'views': 676},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019010700',
#    'views': 632},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019010800',
#    'views': 788},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019010900',
#    'views': 712},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019011000',
#    'views': 673},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019011100',
#    'views': 784},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019011200',
#    'views': 663},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019011300',
#    'views': 685},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019011400',
#    'views': 752},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019011500',
#    'views': 731},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019011600',
#    'views': 779},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019011700',
#    'views': 779},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019011800',
#    'views': 616},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019011900',
#    'views': 502},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019012000',
#    'views': 487},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019012100',
#    'views': 505},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019012200',
#    'views': 567},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019012300',
#    'views': 537},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019012400',
#    'views': 504},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019012500',
#    'views': 574},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019012600',
#    'views': 430},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019012700',
#    'views': 412},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019012800',
#    'views': 486},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019012900',
#    'views': 605},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019013000',
#    'views': 515},
#   {'access': 'all-access',
#    'agent': 'all-agents',
#    'article': 'University_of_North_Texas',
#    'granularity': 'daily',
#    'project': 'en.wikipedia',
#    'timestamp': '2019013100',
#    'views': 489}]}

# %% [markdown]
# **Question 3. (20 points)** Load the JSON data into Pandas Dataframe, and show the first five rows.
#
# ![](https://github.com/wshuyi/github_pub_img/raw/master/assets/2019-02-13-10-57-35-214261.png)

# %%
df=pd.DataFrame.from_dict(data_dict['items'])
df
# Out:
#         access       agent                    article granularity  \
# 0   all-access  all-agents  University_of_North_Texas       daily
# 1   all-access  all-agents  University_of_North_Texas       daily
# 2   all-access  all-agents  University_of_North_Texas       daily
# 3   all-access  all-agents  University_of_North_Texas       daily
# 4   all-access  all-agents  University_of_North_Texas       daily
# 5   all-access  all-agents  University_of_North_Texas       daily
# 6   all-access  all-agents  University_of_North_Texas       daily
# 7   all-access  all-agents  University_of_North_Texas       daily
# 8   all-access  all-agents  University_of_North_Texas       daily
# 9   all-access  all-agents  University_of_North_Texas       daily
# 10  all-access  all-agents  University_of_North_Texas       daily
# 11  all-access  all-agents  University_of_North_Texas       daily
# 12  all-access  all-agents  University_of_North_Texas       daily
# 13  all-access  all-agents  University_of_North_Texas       daily
# 14  all-access  all-agents  University_of_North_Texas       daily
# 15  all-access  all-agents  University_of_North_Texas       daily
# 16  all-access  all-agents  University_of_North_Texas       daily
# 17  all-access  all-agents  University_of_North_Texas       daily
# 18  all-access  all-agents  University_of_North_Texas       daily
# 19  all-access  all-agents  University_of_North_Texas       daily
# 20  all-access  all-agents  University_of_North_Texas       daily
# 21  all-access  all-agents  University_of_North_Texas       daily
# 22  all-access  all-agents  University_of_North_Texas       daily
# 23  all-access  all-agents  University_of_North_Texas       daily
# 24  all-access  all-agents  University_of_North_Texas       daily
# 25  all-access  all-agents  University_of_North_Texas       daily
# 26  all-access  all-agents  University_of_North_Texas       daily
# 27  all-access  all-agents  University_of_North_Texas       daily
# 28  all-access  all-agents  University_of_North_Texas       daily
# 29  all-access  all-agents  University_of_North_Texas       daily
# 30  all-access  all-agents  University_of_North_Texas       daily
#
#          project   timestamp  views
# 0   en.wikipedia  2019010100    732
# 1   en.wikipedia  2019010200    834
# 2   en.wikipedia  2019010300    821
# 3   en.wikipedia  2019010400    719
# 4   en.wikipedia  2019010500    672
# 5   en.wikipedia  2019010600    676
# 6   en.wikipedia  2019010700    632
# 7   en.wikipedia  2019010800    788
# 8   en.wikipedia  2019010900    712
# 9   en.wikipedia  2019011000    673
# 10  en.wikipedia  2019011100    784
# 11  en.wikipedia  2019011200    663
# 12  en.wikipedia  2019011300    685
# 13  en.wikipedia  2019011400    752
# 14  en.wikipedia  2019011500    731
# 15  en.wikipedia  2019011600    779
# 16  en.wikipedia  2019011700    779
# 17  en.wikipedia  2019011800    616
# 18  en.wikipedia  2019011900    502
# 19  en.wikipedia  2019012000    487
# 20  en.wikipedia  2019012100    505
# 21  en.wikipedia  2019012200    567
# 22  en.wikipedia  2019012300    537
# 23  en.wikipedia  2019012400    504
# 24  en.wikipedia  2019012500    574
# 25  en.wikipedia  2019012600    430
# 26  en.wikipedia  2019012700    412
# 27  en.wikipedia  2019012800    486
# 28  en.wikipedia  2019012900    605
# 29  en.wikipedia  2019013000    515
# 30  en.wikipedia  2019013100    489

# %% [markdown]
# **Question 4. (20 points)** Figure out the max and min views and corresponding date.
#
# ![](https://github.com/wshuyi/github_pub_img/raw/master/assets/2019-02-13-10-57-35-195410.png)
#
# ![](https://github.com/wshuyi/github_pub_img/raw/master/assets/2019-02-13-10-57-35-197160.png)

# %%
colums=['timestamp','views']
df=df[colums]
max_view=df.loc[df['views'].idxmax()]
min_view=df.loc[df['views'].idxmin()]
print (max_view)
print (min_view)
# Out:
# timestamp    2019010200
# views               834
# Name: 1, dtype: object
# timestamp    2019012700
# views               412
# Name: 26, dtype: object

# %% [markdown]
# **Question 5. (20 points)** Plot line chart of Pageviews for the whole month.
#
# ![](https://github.com/wshuyi/github_pub_img/raw/master/assets/2019-02-13-10-57-35-197005.png)

# %%
from matplotlib import pyplot

pyplot.plot(df['views'])
